# %% [markdown]
# # **Filtering & Shorting**

# %% [markdown]
# Question . Create the following dummy table in MySQL Workbench using CREATE FUNCTION.
# - Answer :- [sql queries](https://drive.google.com/file/d/1XFOpbcaUu3irbYJynX9ZFbDDtJM9hj18/view?usp=sharing)

# %% [markdown]
#  Q1. Show employees working in either the ‘IT’ or ‘HR’ departments
#  - Answer :-[sql queries](https://drive.google.com/file/d/18TW_Rh6iVAIdnW0BKQdGqKgCMnSH-ruX/view?usp=drive_link)

# %% [markdown]
# Q2. Retrieve employees whose department is in ‘Sales’, ‘IT’, or ‘Finance’.
# - Answer :- [sql queries](https://drive.google.com/file/d/1lM2GKxeCmkGuSjuK7T_x6DMAkMs2IdJb/view?usp=sharing)

# %% [markdown]
# Q3. Display employees whose salary is between ₹50,000 and ₹70,000.
#  - Answer :- [sql queries](https://drive.google.com/file/d/1U3YeqyfTRVF8NfPjCFVoZRdJmHX_9of7/view?usp=sharing)

# %% [markdown]
# Q4.  List employees whose names start with the letter ‘A’.
# - Answer :- [sql queries](https://drive.google.com/file/d/1w3Oh6w8Q2j1uayARpawlJll5OlPqxOQM/view?usp=sharing)

# %% [markdown]
# Q5.  Find employees whose names contain the substring ‘an’.
# - Answer :-[ sql queries](https://drive.google.com/file/d/1iV1iXVdWUvWxiNvdmuoMR1w3MxKP8xs4/view?usp=sharing)

# %% [markdown]
# Q6. Show employees who are from ‘Delhi’ or ‘Mumbai’ and earn more than ₹55,000.
# - Answer :- [sql queries](https://drive.google.com/file/d/1j1b-NdrHB-Z8IGWQTXYSkei0_FgzGEwI/view?usp=sharing)

# %% [markdown]
# Q7. Display all employees except those from the ‘HR’ department.
# - Answer :- [sql queries](https://drive.google.com/file/d/1j1b-NdrHB-Z8IGWQTXYSkei0_FgzGEwI/view?usp=sharing)

# %% [markdown]
# Q8. Get all employees hired between 2019 and 2022, ordered by HireDate (oldest first).
# - Answer :-[sql queries](https://drive.google.com/file/d/1u2SDpLAmhKDugC-5sNO8TJNvYmHwyf65/view?usp=sharing)
